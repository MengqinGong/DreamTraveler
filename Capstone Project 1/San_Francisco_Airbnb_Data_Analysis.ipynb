# %%
# import libraries
% matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pygeocoder import Geocoder
from datetime import date

# %%
# read data and print .info()
calendar = pd.read_csv('sf/calendar.csv', parse_dates = [2])
print(calendar.info())
listings = pd.read_csv('sf/listings.csv')
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610115 entries, 0 to 2610114
# Data columns (total 7 columns):
# listing_id        int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights    int64
# maximum_nights    int64
# dtypes: int64(3), object(4)
# memory usage: 139.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7151 entries, 0 to 7150
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(21), int64(23), object(62)
# memory usage: 5.8+ MB
# None

# %%
# check missing value counts 
print(calendar.isna().sum())
print(listings.isna().sum())

# calendar doesn't have missing value
# listings has missing values in multiple columns
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# summary                                          200
# space                                           1075
# description                                       21
# experiences_offered                                0
# neighborhood_overview                           1902
# notes                                           2743
# transit                                         2020
# access                                          2386
# interaction                                     2292
# house_rules                                     1922
# thumbnail_url                                   7151
# medium_url                                      7151
# picture_url                                        0
# xl_picture_url                                  7151
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      9
# host_about                                      1704
# host_response_time                               725
# host_response_rate                               725
# host_acceptance_rate                            7151
# host_is_superhost                                  0
# host_thumbnail_url                                 0
#                                                 ...
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# first_review                                    1377
# last_review                                     1377
# review_scores_rating                            1421
# review_scores_accuracy                          1425
# review_scores_cleanliness                       1424
# review_scores_checkin                           1427
# review_scores_communication                     1423
# review_scores_location                          1427
# review_scores_value                             1428
# requires_license                                   0
# license                                         2550
# jurisdiction_names                                49
# instant_bookable                                   0
# is_business_travel_ready                           0
# cancellation_policy                                0
# require_guest_profile_picture                      0
# require_guest_phone_verification                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1377
# Length: 106, dtype: int64

# %%
# remove columns with all missing values from listings
listings = listings.dropna(axis=1, how='all')

# remove duplicated rows (if any) from both DataFrames
calendar = calendar.drop_duplicates()
listings = listings.drop_duplicates()

# %%
# drop unrelated columns or columns with duplicated info (e.g drop listing_url since it's providing same info as id)
columns_to_remove = ['listing_url', 'scrape_id', 'last_scraped', 'picture_url', 'host_url', 'host_name', \
                     'host_total_listings_count', 'host_thumbnail_url', 'host_picture_url', \
                     'city', 'state', 'market', 'country_code', 'country',\
                     'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', \
                     'maximum_maximum_nights', 'calendar_last_scraped', 'host_neighbourhood']
listings = listings.drop(columns = columns_to_remove)

# %%
# drop columns with descriptive scripts written by host and experiences_offered column which contains only 'none' 
columns_scripts = ['name', 'summary', 'space', 'description', 'experiences_offered',
       'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
       'host_about']
listings = listings.drop(columns = columns_scripts)

# %%
# drop square_feet column which only 126(<2%) listings have the data
listings = listings.drop(columns = ['square_feet'])

# %%
# check the columns with missing values
listings.isna().sum().sort_values(ascending=False).head(30)
# Out:
# weekly_price                   6000
# monthly_price                  6000
# license                        2550
# house_rules                    1922
# security_deposit               1469
# review_scores_value            1428
# review_scores_location         1427
# review_scores_checkin          1427
# review_scores_accuracy         1425
# review_scores_cleanliness      1424
# review_scores_communication    1423
# review_scores_rating           1421
# reviews_per_month              1377
# last_review                    1377
# first_review                   1377
# cleaning_fee                    802
# host_response_rate              725
# host_response_time              725
# zipcode                         205
# jurisdiction_names               49
# bathrooms                        21
# host_location                     9
# beds                              7
# bedrooms                          2
# is_location_exact                 0
# host_id                           0
# host_since                        0
# accommodates                      0
# room_type                         0
# property_type                     0
# dtype: int64

# %%
# create additional_house_rule based on the value in house_rules and remove house_rules
listings['additional_house_rule'] = listings.house_rules.notna()
listings = listings.drop(columns=['house_rules'])

# %%
# fill missing values in zipcode column based on coordinates of the listing
def get_zipcode(lat, lon):
    location = Geocoder('AIzaSyDXPHG6YGqk7Fz-Iwv1DGgeTBJNDzkkOYk').reverse_geocode(lat, lon)
    return location.postal_code

for index, row in listings[listings.zipcode.isna()].iterrows():
    try:
        listings.loc[index, 'zipcode'] = get_zipcode(row['latitude'], row['longitude'])
    except:
        listings.loc[index, 'zipcode'] = np.nan

# %%
# check values in zipcode column
listings.zipcode.value_counts()
# Out:
# 94110    937
# 94117    623
# 94114    608
# 94109    509
# 94103    424
# 94102    401
# 94107    368
# 94112    337
# 94122    318
# 94115    313
# 94131    276
# 94133    235
# 94108    224
# 94123    212
# 94118    205
# 94116    196
# 94121    181
# 94124    153
# 94127    117
# 94105    117
# 94134    116
# 94158     87
# 94132     77
# 94111     45
# 94104     12
# 94113      1
# CA         1
# Name: zipcode, dtype: int64

# %%
listings[listings.zipcode == 'CA'][['latitude', 'longitude','zipcode']]
# Out:
#       latitude  longitude zipcode
# 6561  37.72792 -122.44029      CA

# %%
# manual correct 1 row
listings.loc[6561,'zipcode'] = get_zipcode(listings.latitude[6561], listings.longitude[6561])

# %%
# host_location, jurisdiction_names: drop rows with missing values
listings = listings.dropna(subset=['host_location', 'jurisdiction_names'])

# %%
# convert host_response_rate to float
listings.host_response_rate = listings.host_response_rate.str[:-1].astype(float)
listings.host_response_rate = listings.host_response_rate / 100

# %%
# find median of host_response_time: within an hour
listings.host_response_time.value_counts()
# Out:
# within an hour        4319
# within a few hours    1271
# within a day           706
# a few days or more      75
# Name: host_response_time, dtype: int64

# %%
# fill review_scores, host_response_rate, host_response_time with with median, reviews_per_month with 0, 
# first_review, last_review with date of today
columns_fill_with_median = ['review_scores_rating', 'review_scores_communication', 'review_scores_cleanliness', \
                           'review_scores_accuracy', 'review_scores_checkin', 'review_scores_location', \
                           'review_scores_value', 'host_response_rate']

for column in columns_fill_with_median:
    median = listings[column].median()
    listings[column] = listings[column].fillna(median)

listings.host_response_time = listings.host_response_time.fillna('within an hour')    
listings.reviews_per_month = listings.reviews_per_month.fillna(0)
listings.last_review = listings.last_review.fillna(date.today())
listings.first_review = listings.first_review.fillna(date.today())

# %%
# fill missing values with median for bathrooms, bedrooms and beds columns
listings.bathrooms = listings.bathrooms.fillna(listings.bathrooms.median())
listings.bedrooms = listings.bedrooms.fillna(listings.bedrooms.median())
listings.beds = listings.beds.fillna(listings.beds.median())

# %%
# fill missing values in weekly_price and monthly_price based on price column
listings.price = listings.price.str.replace(',', '')
listings.price = listings.price.str[1:].astype(float)

# %%
listings.weekly_price = listings.weekly_price.str.replace(',', '').str.replace('$', '').astype(float)
listings.monthly_price = listings.monthly_price.str.replace(',', '').str.replace('$', '').astype(float)
listings.weekly_price = listings.weekly_price.fillna(listings.price * 7)
listings.monthly_price = listings.monthly_price.fillna(listings.price * 30)

# %%
# fill missing values with 0 for security_deposit and cleaning fee column
listings.security_deposit = listings.security_deposit.str.replace(',', '').str.replace('$', '').astype(float)
listings.cleaning_fee = listings.cleaning_fee.str.replace(',', '').str.replace('$', '').astype(float)
listings.security_deposit = listings.security_deposit.fillna(0)
listings.cleaning_fee = listings.cleaning_fee.fillna(0)

# %%
# create have_license based on the value in license and remove license
listings['have_license'] = listings.license.notna()
listings = listings.drop(columns=['license'])

# %%
# check for outliers
print(listings.iloc[:, :30].describe())
print(listings.iloc[:, 30:50].describe())
print(listings.iloc[:, 50:].describe())
# Out:
#                  id       host_id  host_response_rate  host_listings_count  \
# count  7.093000e+03  7.093000e+03         7093.000000          7093.000000
# mean   1.659018e+07  4.549157e+07            0.967730            51.577612
# std    1.047275e+07  6.235286e+07            0.110412           175.467568
# min    9.580000e+02  4.600000e+01            0.000000             0.000000
# 25%    6.764924e+06  3.685746e+06            1.000000             1.000000
# 50%    1.786322e+07  1.495030e+07            1.000000             2.000000
# 75%    2.554714e+07  5.910047e+07            1.000000             8.000000
# max    3.284519e+07  2.460479e+08            1.000000          1199.000000
#
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  7093.000000  7093.000000   7093.000000  7093.000000  7093.000000
# mean     37.766092  -122.430446      3.201466     1.327576     1.342591
# std       0.022215     0.026802      1.914969     0.794761     0.932546
# min      37.708380  -122.513060      1.000000     0.000000     0.000000
# 25%      37.751350  -122.442710      2.000000     1.000000     1.000000
# 50%      37.767750  -122.425380      2.000000     1.000000     1.000000
# 75%      37.784740  -122.411030      4.000000     1.500000     2.000000
# max      37.810310  -122.369790     16.000000    14.000000    14.000000
#
#               beds         price  weekly_price  monthly_price
# count  7093.000000   7093.000000   7093.000000    7093.000000
# mean      1.761314    213.043423   1462.535598    6160.500070
# std       1.173530    300.301956   1938.704280    8370.086477
# min       0.000000      0.000000      0.000000       0.000000
# 25%       1.000000    100.000000    700.000000    2970.000000
# 50%       1.000000    150.000000   1050.000000    4500.000000
# 75%       2.000000    237.000000   1620.000000    6750.000000
# max      14.000000  10000.000000  70000.000000  300000.000000
#        security_deposit  cleaning_fee  guests_included  minimum_nights  \
# count       7093.000000   7093.000000      7093.000000    7.093000e+03
# mean         372.962921     94.011138         1.727619    1.411470e+04
# std          697.949166     83.611789         1.342910    1.187367e+06
# min            0.000000      0.000000         1.000000    1.000000e+00
# 25%            0.000000     35.000000         1.000000    2.000000e+00
# 50%          150.000000     80.000000         1.000000    4.000000e+00
# 75%          500.000000    128.000000         2.000000    3.000000e+01
# max         5100.000000    700.000000        16.000000    1.000000e+08
#
#        maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# count    7.093000e+03            7.093000e+03            7.093000e+03
# mean     1.477767e+04            1.413661e+04            1.477497e+04
# std      1.187419e+06            1.187367e+06            1.187419e+06
# min      1.000000e+00            1.000000e+00            1.000000e+00
# 25%      2.900000e+01            2.000000e+00            2.900000e+01
# 50%      1.800000e+02            4.000000e+00            1.800000e+02
# 75%      1.125000e+03            3.000000e+01            1.125000e+03
# max      1.000000e+08            1.000000e+08            1.000000e+08
#
#        availability_30  availability_60  availability_90  availability_365  \
# count      7093.000000      7093.000000      7093.000000       7093.000000
# mean          8.683914        21.869026        37.023262        148.712956
# std          10.197758        21.074858        32.067609        128.528549
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         3.000000         26.000000
# 50%           4.000000        16.000000        34.000000        120.000000
# 75%          15.000000        38.000000        65.000000        272.000000
# max          30.000000        60.000000        90.000000        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# count        7093.000000            7093.000000           7093.000000
# mean           43.748484              14.760891             96.049485
# std            72.710625              22.812357              6.244045
# min             0.000000               0.000000             20.000000
# 25%             1.000000               0.000000             95.000000
# 50%            12.000000               3.000000             98.000000
# 75%            54.000000              20.000000             99.000000
# max           677.000000             152.000000            100.000000
#
#        review_scores_accuracy
# count             7093.000000
# mean                 9.821655
# std                  0.597206
# min                  2.000000
# 25%                 10.000000
# 50%                 10.000000
# 75%                 10.000000
# max                 10.000000
#        review_scores_cleanliness  review_scores_checkin  \
# count                7093.000000            7093.000000
# mean                    9.701819               9.895249
# std                     0.697302               0.450163
# min                     2.000000               2.000000
# 25%                    10.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  7093.000000             7093.000000
# mean                      9.872550                9.720288
# std                       0.523932                0.657836
# min                       2.000000                2.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          7093.000000                     7093.000000
# mean              9.524602                       16.205978
# std               0.748655                       40.169059
# min               2.000000                        1.000000
# 25%               9.000000                        1.000000
# 50%              10.000000                        2.000000
# 75%              10.000000                        6.000000
# max              10.000000                      204.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7093.000000
# mean                                     13.460595
# std                                      39.860696
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     204.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7093.000000
# mean                                       2.388693
# std                                        6.230795
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       51.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  7093.000000        7093.000000
# mean                                      0.356690           1.503604
# std                                       2.376136           1.935830
# min                                       0.000000           0.000000
# 25%                                       0.000000           0.120000
# 50%                                       0.000000           0.640000
# 75%                                       0.000000           2.270000
# max                                      22.000000          12.800000

# %%
# check the host with 1199 listings in total, seems to be a company providing apartment rentals
print(listings.loc[listings.host_listings_count == 1199])
# Out:
#             id   host_id  host_since  \
# 3674  18563010  12243051  2014-02-14
# 3754  18894263  12243051  2014-02-14
# 3757  18908177  12243051  2014-02-14
# 3793  19140088  12243051  2014-02-14
# 3956  20087573  12243051  2014-02-14
# 4029  20426652  12243051  2014-02-14
# 4084  20704455  12243051  2014-02-14
# 4312  21488120  12243051  2014-02-14
# 4431  21827805  12243051  2014-02-14
# 4631  22669703  12243051  2014-02-14
# 4929  23701076  12243051  2014-02-14
# 4930  23701710  12243051  2014-02-14
# 4977  23900758  12243051  2014-02-14
# 4978  23901551  12243051  2014-02-14
# 4979  23902403  12243051  2014-02-14
# 5026  24060785  12243051  2014-02-14
# 5039  24101246  12243051  2014-02-14
# 5040  24102946  12243051  2014-02-14
# 5123  24465675  12243051  2014-02-14
# 5128  24471190  12243051  2014-02-14
# 5147  24539245  12243051  2014-02-14
# 5148  24541441  12243051  2014-02-14
# 5159  24602029  12243051  2014-02-14
# 5195  24770212  12243051  2014-02-14
# 5237  24987647  12243051  2014-02-14
# 5238  24990444  12243051  2014-02-14
# 5239  24990993  12243051  2014-02-14
# 5305  25370853  12243051  2014-02-14
# 5306  25371831  12243051  2014-02-14
# 5309  25376440  12243051  2014-02-14
# 5310  25376448  12243051  2014-02-14
# 5312  25377087  12243051  2014-02-14
# 5313  25377521  12243051  2014-02-14
# 5339  25509034  12243051  2014-02-14
# 5360  25677242  12243051  2014-02-14
#
#                                  host_location host_response_time  \
# 3674  San Francisco, California, United States     within an hour
# 3754  San Francisco, California, United States     within an hour
# 3757  San Francisco, California, United States     within an hour
# 3793  San Francisco, California, United States     within an hour
# 3956  San Francisco, California, United States     within an hour
# 4029  San Francisco, California, United States     within an hour
# 4084  San Francisco, California, United States     within an hour
# 4312  San Francisco, California, United States     within an hour
# 4431  San Francisco, California, United States     within an hour
# 4631  San Francisco, California, United States     within an hour
# 4929  San Francisco, California, United States     within an hour
# 4930  San Francisco, California, United States     within an hour
# 4977  San Francisco, California, United States     within an hour
# 4978  San Francisco, California, United States     within an hour
# 4979  San Francisco, California, United States     within an hour
# 5026  San Francisco, California, United States     within an hour
# 5039  San Francisco, California, United States     within an hour
# 5040  San Francisco, California, United States     within an hour
# 5123  San Francisco, California, United States     within an hour
# 5128  San Francisco, California, United States     within an hour
# 5147  San Francisco, California, United States     within an hour
# 5148  San Francisco, California, United States     within an hour
# 5159  San Francisco, California, United States     within an hour
# 5195  San Francisco, California, United States     within an hour
# 5237  San Francisco, California, United States     within an hour
# 5238  San Francisco, California, United States     within an hour
# 5239  San Francisco, California, United States     within an hour
# 5305  San Francisco, California, United States     within an hour
# 5306  San Francisco, California, United States     within an hour
# 5309  San Francisco, California, United States     within an hour
# 5310  San Francisco, California, United States     within an hour
# 5312  San Francisco, California, United States     within an hour
# 5313  San Francisco, California, United States     within an hour
# 5339  San Francisco, California, United States     within an hour
# 5360  San Francisco, California, United States     within an hour
#
#       host_response_rate host_is_superhost  host_listings_count  \
# 3674                0.94                 f                 1199
# 3754                0.94                 f                 1199
# 3757                0.94                 f                 1199
# 3793                0.94                 f                 1199
# 3956                0.94                 f                 1199
# 4029                0.94                 f                 1199
# 4084                0.94                 f                 1199
# 4312                0.94                 f                 1199
# 4431                0.94                 f                 1199
# 4631                0.94                 f                 1199
# 4929                0.94                 f                 1199
# 4930                0.94                 f                 1199
# 4977                0.94                 f                 1199
# 4978                0.94                 f                 1199
# 4979                0.94                 f                 1199
# 5026                0.94                 f                 1199
# 5039                0.94                 f                 1199
# 5040                0.94                 f                 1199
# 5123                0.94                 f                 1199
# 5128                0.94                 f                 1199
# 5147                0.94                 f                 1199
# 5148                0.94                 f                 1199
# 5159                0.94                 f                 1199
# 5195                0.94                 f                 1199
# 5237                0.94                 f                 1199
# 5238                0.94                 f                 1199
# 5239                0.94                 f                 1199
# 5305                0.94                 f                 1199
# 5306                0.94                 f                 1199
# 5309                0.94                 f                 1199
# 5310                0.94                 f                 1199
# 5312                0.94                 f                 1199
# 5313                0.94                 f                 1199
# 5339                0.94                 f                 1199
# 5360                0.94                 f                 1199
#
#                                      host_verifications host_has_profile_pic  \
# 3674  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 3754  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 3757  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 3793  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 3956  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4029  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4084  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4312  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4431  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4631  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4929  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4930  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4977  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4978  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 4979  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5026  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5039  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5040  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5123  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5128  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5147  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5148  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5159  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5195  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5237  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5238  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5239  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5305  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5306  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5309  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5310  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5312  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5313  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5339  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
# 5360  ['email', 'phone', 'manual_offline', 'jumio', ...                    t
#
#          ...               cancellation_policy require_guest_profile_picture  \
# 3674     ...       strict_14_with_grace_period                             f
# 3754     ...       strict_14_with_grace_period                             f
# 3757     ...       strict_14_with_grace_period                             f
# 3793     ...       strict_14_with_grace_period                             f
# 3956     ...       strict_14_with_grace_period                             f
# 4029     ...       strict_14_with_grace_period                             f
# 4084     ...       strict_14_with_grace_period                             f
# 4312     ...       strict_14_with_grace_period                             f
# 4431     ...       strict_14_with_grace_period                             f
# 4631     ...       strict_14_with_grace_period                             f
# 4929     ...       strict_14_with_grace_period                             f
# 4930     ...       strict_14_with_grace_period                             f
# 4977     ...       strict_14_with_grace_period                             f
# 4978     ...       strict_14_with_grace_period                             f
# 4979     ...       strict_14_with_grace_period                             f
# 5026     ...       strict_14_with_grace_period                             f
# 5039     ...       strict_14_with_grace_period                             f
# 5040     ...       strict_14_with_grace_period                             f
# 5123     ...       strict_14_with_grace_period                             f
# 5128     ...       strict_14_with_grace_period                             f
# 5147     ...       strict_14_with_grace_period                             f
# 5148     ...       strict_14_with_grace_period                             f
# 5159     ...       strict_14_with_grace_period                             f
# 5195     ...       strict_14_with_grace_period                             f
# 5237     ...       strict_14_with_grace_period                             f
# 5238     ...       strict_14_with_grace_period                             f
# 5239     ...       strict_14_with_grace_period                             f
# 5305     ...       strict_14_with_grace_period                             f
# 5306     ...       strict_14_with_grace_period                             f
# 5309     ...       strict_14_with_grace_period                             f
# 5310     ...       strict_14_with_grace_period                             f
# 5312     ...       strict_14_with_grace_period                             f
# 5313     ...       strict_14_with_grace_period                             f
# 5339     ...       strict_14_with_grace_period                             f
# 5360     ...       strict_14_with_grace_period                             f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 3674                                f                             35
# 3754                                f                             35
# 3757                                f                             35
# 3793                                f                             35
# 3956                                f                             35
# 4029                                f                             35
# 4084                                f                             35
# 4312                                f                             35
# 4431                                f                             35
# 4631                                f                             35
# 4929                                f                             35
# 4930                                f                             35
# 4977                                f                             35
# 4978                                f                             35
# 4979                                f                             35
# 5026                                f                             35
# 5039                                f                             35
# 5040                                f                             35
# 5123                                f                             35
# 5128                                f                             35
# 5147                                f                             35
# 5148                                f                             35
# 5159                                f                             35
# 5195                                f                             35
# 5237                                f                             35
# 5238                                f                             35
# 5239                                f                             35
# 5305                                f                             35
# 5306                                f                             35
# 5309                                f                             35
# 5310                                f                             35
# 5312                                f                             35
# 5313                                f                             35
# 5339                                f                             35
# 5360                                f                             35
#
#      calculated_host_listings_count_entire_homes  \
# 3674                                          35
# 3754                                          35
# 3757                                          35
# 3793                                          35
# 3956                                          35
# 4029                                          35
# 4084                                          35
# 4312                                          35
# 4431                                          35
# 4631                                          35
# 4929                                          35
# 4930                                          35
# 4977                                          35
# 4978                                          35
# 4979                                          35
# 5026                                          35
# 5039                                          35
# 5040                                          35
# 5123                                          35
# 5128                                          35
# 5147                                          35
# 5148                                          35
# 5159                                          35
# 5195                                          35
# 5237                                          35
# 5238                                          35
# 5239                                          35
# 5305                                          35
# 5306                                          35
# 5309                                          35
# 5310                                          35
# 5312                                          35
# 5313                                          35
# 5339                                          35
# 5360                                          35
#
#      calculated_host_listings_count_private_rooms  \
# 3674                                            0
# 3754                                            0
# 3757                                            0
# 3793                                            0
# 3956                                            0
# 4029                                            0
# 4084                                            0
# 4312                                            0
# 4431                                            0
# 4631                                            0
# 4929                                            0
# 4930                                            0
# 4977                                            0
# 4978                                            0
# 4979                                            0
# 5026                                            0
# 5039                                            0
# 5040                                            0
# 5123                                            0
# 5128                                            0
# 5147                                            0
# 5148                                            0
# 5159                                            0
# 5195                                            0
# 5237                                            0
# 5238                                            0
# 5239                                            0
# 5305                                            0
# 5306                                            0
# 5309                                            0
# 5310                                            0
# 5312                                            0
# 5313                                            0
# 5339                                            0
# 5360                                            0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 3674                                            0               0.21
# 3754                                            0               0.12
# 3757                                            0               0.10
# 3793                                            0               0.00
# 3956                                            0               0.18
# 4029                                            0               0.06
# 4084                                            0               0.16
# 4312                                            0               0.44
# 4431                                            0               0.11
# 4631                                            0               0.18
# 4929                                            0               0.00
# 4930                                            0               0.00
# 4977                                            0               0.00
# 4978                                            0               0.00
# 4979                                            0               0.00
# 5026                                            0               0.11
# 5039                                            0               0.00
# 5040                                            0               0.11
# 5123                                            0               0.12
# 5128                                            0               0.00
# 5147                                            0               0.00
# 5148                                            0               0.00
# 5159                                            0               0.00
# 5195                                            0               0.00
# 5237                                            0               0.00
# 5238                                            0               0.12
# 5239                                            0               0.00
# 5305                                            0               0.00
# 5306                                            0               0.00
# 5309                                            0               0.00
# 5310                                            0               0.19
# 5312                                            0               0.00
# 5313                                            0               0.00
# 5339                                            0               0.00
# 5360                                            0               0.00
#
#      additional_house_rule have_license
# 3674                  True        False
# 3754                  True        False
# 3757                  True        False
# 3793                  True        False
# 3956                  True        False
# 4029                  True        False
# 4084                  True        False
# 4312                  True        False
# 4431                  True        False
# 4631                  True        False
# 4929                  True        False
# 4930                  True        False
# 4977                  True        False
# 4978                  True        False
# 4979                  True        False
# 5026                  True        False
# 5039                  True        False
# 5040                  True        False
# 5123                  True        False
# 5128                  True        False
# 5147                  True        False
# 5148                  True        False
# 5159                  True        False
# 5195                  True        False
# 5237                  True        False
# 5238                  True        False
# 5239                  True        False
# 5305                  True        False
# 5306                  True        False
# 5309                  True        False
# 5310                  True        False
# 5312                  True        False
# 5313                  True        False
# 5339                  True        False
# 5360                  True        False
#
# [35 rows x 69 columns]

# %%
calendar.price = calendar.price.str[1:]

# %%
calendar.price = calendar.price.str.replace(',', '').astype(float)

# %%
print(calendar.describe())
# Out:
#          listing_id         price  minimum_nights  maximum_nights
# count  2.610115e+06  2.610115e+06    2.610115e+06    2.610115e+06
# mean   1.666813e+07  2.275084e+02    1.402237e+04    1.466002e+04
# std    1.047705e+07  3.400472e+02    1.182459e+06    1.182511e+06
# min    9.580000e+02  1.000000e+01    1.000000e+00    1.000000e+00
# 25%    6.864929e+06  1.060000e+02    2.000000e+00    2.900000e+01
# 50%    1.803718e+07  1.600000e+02    4.000000e+00    1.800000e+02
# 75%    2.568296e+07  2.500000e+02    3.000000e+01    1.125000e+03
# max    3.284519e+07  1.000000e+04    1.000000e+08    1.000000e+08

# %%
# export to csv
listings.to_csv('listings_clean.csv')
calendar.to_csv('calendar_clean.csv')
